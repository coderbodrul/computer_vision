# %%
! pip install kaggle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! mkdir ~/.kaggle

# %%
# !cp '/content/drive/MyDrive/Colab Notebooks/kaggle_credentials/kaggle.json' ~/.kaggle/
# Out:
# cp: cannot stat '/content/drive/MyDrive/Colab Notebooks/kaggle_credentials/kaggle.json': No such file or directory

# %%
! chmod 600 ~/.kaggle/kaggle.json
# Out:
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
! mkdir /content/kaggle_data
# Out:
# mkdir: cannot create directory ‘/content/kaggle_data’: File exists

# %%
# %%shell
# ls /
# if [ ! -d "/root/.kaggle/kaggle.json" ]; then
#   echo "$DIRECTORY does not exist."
# fi
# Out:
# bin			    datalab  kaggle  libx32		       opt   sbin  tools
# boot			    dev      lib     media		       proc  srv   usr
# content			    etc      lib32   mnt		       root  sys   var
# cuda-keyring_1.0-1_all.deb  home     lib64   NGC-DL-CONTAINER-LICENSE  run   tmp
#  does not exist.

# %%
! kaggle datasets download -p /content/kaggle_data tenxengineers/denoising-dataset-multiple-iso-levels
# Out:
# Dataset URL: https://www.kaggle.com/datasets/tenxengineers/denoising-dataset-multiple-iso-levels
# License(s): CC-BY-SA-4.0
# denoising-dataset-multiple-iso-levels.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
! unzip /content/kaggle_data/denoising-dataset-multiple-iso-levels.zip -d /content/kaggle_data/denoising-dataset-multiple-iso-levels/
# Out:
# Archive:  /content/kaggle_data/denoising-dataset-multiple-iso-levels.zip
# replace /content/kaggle_data/denoising-dataset-multiple-iso-levels/AlphaISP - Denoising Dataset/AlphaISP - Denoising Dataset/PNG Data/2DNR Denoising/Ground Truth/AlphaISP_2592x1536_8bits_Scene1.png? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive
from google.colab.patches import cv2_imshow

# %%
# Create a list of image paths
txt_files = []
for root, dirs, files in os.walk("/content/kaggle_data/denoising-dataset-multiple-iso-levels/AlphaISP - Denoising Dataset/AlphaISP - Denoising Dataset"):
    for file in files:
        if file.endswith("AlphaISP_2592x1536_8bits_Scene4.png"):
            txt_files.append(os.path.join(root, file))

# %%
def display_image(title, image):
    plt.figure(figsize=(7, 7))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.axis('off')
    plt.show()

# %%
from skimage import io

for noisy_image in txt_files:
  print(noisy_image)
  plt.figure()
  plt.imshow(io.imread(noisy_image))
plt.show()
# Out:
# /content/kaggle_data/denoising-dataset-multiple-iso-levels/AlphaISP - Denoising Dataset/AlphaISP - Denoising Dataset/PNG Data/Bayer Denoising/Noised/AlphaISP_2592x1536_8bits_Scene4.png
# /content/kaggle_data/denoising-dataset-multiple-iso-levels/AlphaISP - Denoising Dataset/AlphaISP - Denoising Dataset/PNG Data/Bayer Denoising/Ground Truth/AlphaISP_2592x1536_8bits_Scene4.png
# /content/kaggle_data/denoising-dataset-multiple-iso-levels/AlphaISP - Denoising Dataset/AlphaISP - Denoising Dataset/PNG Data/2DNR Denoising/Noised/AlphaISP_2592x1536_8bits_Scene4.png
# /content/kaggle_data/denoising-dataset-multiple-iso-levels/AlphaISP - Denoising Dataset/AlphaISP - Denoising Dataset/PNG Data/2DNR Denoising/Ground Truth/AlphaISP_2592x1536_8bits_Scene4.png

# %%
# Process each image in the txt_files list
for image_path in txt_files:
    # Load the image
    image = cv2.imread(image_path)
    display_image('Original Image', image)

    # 1. Noise Reduction using Gaussian Blurring
    noise_reduced = cv2.GaussianBlur(image, (5, 5), 0)
    display_image('Noise Reduced', noise_reduced)

    # 2. Change Detection
    # Assume the corresponding clean image is available at the same location with a different name
    dirty_image_path = image_path.replace("AlphaISP_2592x1536_8bits_Scene4.png", "AlphaISP_2592x1536_8bits_Scene4_dirty.png")

    if os.path.exists(dirty_image_path):
        dirty_image = cv2.imread(dirty_image_path)
        display_image('Modified Image for Change Detection', dirty_image)

        # Compute the absolute difference between the noisy and clean images
        change_detected = cv2.absdiff(image, dirty_image)
        display_image('Change Detected', change_detected)
    else:
        print(f"Clean image not found for {image_path}")
        change_detected = None

    # 3. Masking
    # Create a binary mask
    mask = np.zeros(image.shape[:2], dtype="uint8")
    cv2.rectangle(mask, (1450,50), (1650, 200), 255, -1)
    display_image('Mask', mask)

    # Apply the mask to the noise-reduced image
    masked_image = cv2.bitwise_and(noise_reduced, noise_reduced, mask=mask)
    display_image('Masked Image', masked_image)
    break

print("Done")
# Out:
# Clean image not found for /content/kaggle_data/denoising-dataset-multiple-iso-levels/AlphaISP - Denoising Dataset/AlphaISP - Denoising Dataset/PNG Data/Bayer Denoising/Noised/AlphaISP_2592x1536_8bits_Scene4.png
# Done
